# %%
import requests
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from bs4 import BeautifulSoup

# %%
url = 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%EC%A0%9C%EC%A3%BC%EB%8F%84'
resp = requests.get(url)

soup = BeautifulSoup(resp.text, 'html.parser')
soup
# Out:
# <!DOCTYPE doctype html>
# ...

# %%
title = soup.find_all('a', class_ = 'news_tit')
title
# Out:
# [<a class="news_tit" href="https://news.bbsi.co.kr/news/articleView.html?idxno=3021061" onclick="return goOtherCR(this, 'a=nws_all*b.tit&amp;r=1&amp;i=8800041E_000000000000000000296859&amp;g=5019.0000296859&amp;u='+urlencode(this.href));" target="_blank" title="제주도, 올해 공무원 214명 뽑는다"><mark>제주도</mark>, 올해 공무원 214명 뽑는다</a>,
#  <a class="news_tit" href="https://www.nocutnews.co.kr/news/5495710" onclick="return goOtherCR(this, 'a=nws_all*a.tit&amp;r=4&amp;i=88000112_000000000000000003464972&amp;g=079.0003464972&amp;u='+urlencode(this.href));" target="_blank" title='제주도의회 박원철·홍명환 "갈등 조장 국민의힘 작태 규탄"'><mark>제주도</mark>의회 박원철·홍명환 "갈등 조장 국민의힘 작태 규탄"</a>,
#  <a class="news_tit" href="http://news.tf.co.kr/read/national/1841706.htm" onclick="return goOtherCR(this, 'a=nws_all*a.tit&amp;r=7&amp;i=881999s8_000000000000000000066595&amp;g=629.0000066595&amp;u='+urlencode(this.href));" target="_blank" title="제주도, 설 연휴 종합상황실 운영...비상근무체계 돌입"><mark>제주도</mark>, 설 연휴 종합상황실 운영...비상근무체계 돌입</a>,
# ...

# %%
all_title = []
for item in title:
    all_title.append(item.get_text())
all_title
# Out:
# ['제주도, 올해 공무원 214명 뽑는다',
#  '제주도의회 박원철·홍명환 "갈등 조장 국민의힘 작태 규탄"',
#  '제주도, 설 연휴 종합상황실 운영...비상근무체계 돌입',
#  '예약 꽉찬 제주도…丁총리 “여행 자제해달라” 호소']

# %%
chromedriver_dir = r'C:\Users\yonpo\Downloads\chromedriver_win32\chromedriver.exe'
driver = webdriver.Chrome(chromedriver_dir)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# ~\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     774                                 errread, errwrite,
# --> 775                                 restore_signals, start_new_session)
#     776         except:
#
# ...
